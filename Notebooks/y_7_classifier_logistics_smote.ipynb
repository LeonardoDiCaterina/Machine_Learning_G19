# %% [markdown]
# # function

# %%
import sys
sys.path.append('../Library')

from data_prep import PreProcessor1

import library_leo as leo

# %% [markdown]
# # FEATURENUMBER =  '7'

# %%
FEATURENUMBER = '7'

# %%
# supppress warnings
import warnings
warnings.filterwarnings("ignore")
# install libraries
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
from math import log

# %%
# get the data
train_path = "../Data/train_data.csv"
test_path = "../Data/test_data.csv"
# Replace 'Column29' with the actual column name that has mixed types
dtype = {'Column29': 'str'}

train = pd.read_csv(train_path, index_col='Claim Identifier',
                    dtype=dtype, low_memory=False)
test = pd.read_csv(test_path, index_col='Claim Identifier',
                   dtype=dtype, low_memory=False)

# %% [markdown]
# ## generate majority target

# %%
train = train.dropna(subset=['Claim Injury Type'])
y = train['Claim Injury Type']
train = train.dropna(subset=['Claim Injury Type'])
y = train['Claim Injury Type']
y_str = y.str[:1]

# %%
# import one hot encoder
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder()
encoder.fit(y_str.values.reshape(-1,1))
y_hot = encoder.transform(y_str.values.reshape(-1,1)).toarray()
y_hot = pd.DataFrame(y_hot, columns=encoder.get_feature_names_out(['Claim Injury Type']), index = y_str.index)
y_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 574026 entries, 5393875 to 6165075
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Claim Injury Type_1  574026 non-null  float64
#  1   Claim Injury Type_2  574026 non-null  float64
#  2   Claim Injury Type_3  574026 non-null  float64
#  3   Claim Injury Type_4  574026 non-null  float64
#  4   Claim Injury Type_5  574026 non-null  float64
#  5   Claim Injury Type_6  574026 non-null  float64
#  6   Claim Injury Type_7  574026 non-null  float64
#  7   Claim Injury Type_8  574026 non-null  float64
# dtypes: float64(8)
# memory usage: 39.4 MB

# %%
y_int = y_str.astype(int)
X = train.drop(columns=['Claim Injury Type'])
# partition the data X, y and y_2bin
X_train, X_valid, y_hot_train,y_hot_valid = train_test_split(
    X, y_hot, test_size=0.2, random_state=0)

# %%
pr = PreProcessor1()
print("------------updates---------------------")
pr.update_casted_cols()
print("------------set_casting---------------------")
pr.set_castings(X_train)
print("------------pipeline---------------------")
df_train = pr.cast_pipeline(X_train)
print("df after cast_pipeline:", df_train.shape)
print("------------fillna---------------------")
pr.update_fillna_list(df_train)   
df_train = pr.fillna_pipeline(df_train)
print("df after fillna_pipeline:", df_train.shape)
print("------------transformation---------------------")
pr.set_transformations(df_train)
df_train = pr.transformation_pipeline(df_train)
print("df after transformation_pipeline:", df_train.shape)
df_train= pr.scaling_pipeline(df_train)
df_train = df_train.drop(columns=['Agreement Reached', 'WCB Decision'])
df_train.info()
# Out:
# ------------updates---------------------
# ------------set_casting---------------------
# Columns that are not casted:
# -WCB Decision: object
# ------------pipeline---------------------
# Feature Carrier Type is already in scaling list
# Feature Zip Code is already in scaling list
# 'Industry Code Description'
# -Column Industry Code Description not found
# df after cast_pipeline: (459220, 26)
# ------------fillna---------------------
# extended fillna_list: [('Age at Injury', 'median'), ('Average Weekly Wage', 'median'), ('Birth Year', 'median'), ('IME-4 Count', 'median'), ('Industry Code', 'median'), ('WCIO Cause of Injury Code', 'median'), ('WCIO Nature of Injury Code', 'median'), ('WCIO Part Of Body Code', 'median'), ('Zip Code', 'median'), ('Agreement Reached', 'median'), ('Number of Dependents', 'median'), ('Accident Date', 'mode'), ('Alternative Dispute Resolution', 'mode'), ('Assembly Date', 'mode'), ('Attorney/Representative', 'mode'), ('C-2 Date', 'mode'), ('C-3 Date', 'mode'), ('Carrier Name', 'mode'), ('Carrier Type', 'mode'), ('County of Injury', 'mode'), ('COVID-19 Indicator', 'mode'), ('District Name', 'mode'), ('First Hearing Date', 'mode'), ('Gender', 'mode'), ('Medical Fee Region', 'mode'), ('WCB Decision', 'mode')]
# nans in the beginning: 1108552
# Column Age at Injury is filled with median ->num nan: 0
# Column Average Weekly Wage is filled with median ->num nan: 0
# Column Birth Year is filled with median ->num nan: 0
# Column IME-4 Count is filled with median ->num nan: 0
# Column Industry Code is filled with median ->num nan: 0
# Column WCIO Cause of Injury Code is filled with median ->num nan: 0
# Column WCIO Nature of Injury Code is filled with median ->num nan: 0
# Column WCIO Part Of Body Code is filled with median ->num nan: 0
# Column Zip Code is filled with median ->num nan: 0
# Column Agreement Reached is filled with median ->num nan: 0
# Column Number of Dependents is filled with median ->num nan: 0
# Column Accident Date is filled with mode ->num nan: 0
# Column Alternative Dispute Resolution is filled with mode ->num nan: 0
# Column Assembly Date is filled with mode ->num nan: 0
# Column Attorney/Representative is filled with mode ->num nan: 0
# Column C-2 Date is filled with mode ->num nan: 0
# Column C-3 Date is filled with mode ->num nan: 0
# Column Carrier Name is filled with mode ->num nan: 0
# Column Carrier Type is filled with mode ->num nan: 0
# Column County of Injury is filled with mode ->num nan: 0
# Column COVID-19 Indicator is filled with mode ->num nan: 0
# Column District Name is filled with mode ->num nan: 0
# Column First Hearing Date is filled with mode ->num nan: 0
# Column Gender is filled with mode ->num nan: 0
# Column Medical Fee Region is filled with mode ->num nan: 0
# Column WCB Decision is filled with mode ->num nan: 0
# nans in the end: 0
# df after fillna_pipeline: (459220, 26)
# ------------transformation---------------------
# Warning: there are duplicates in the transformation list
# Columns that are not transformed:
# -Average Weekly Wage: float64
# -District Name: object
# -Agreement Reached: Int64
# -Carrier Name: string
# -WCB Decision: object
# -Number of Dependents: Int64
# -IME-4 Count: Int64
# -Gender: string
# -Birth Year: Int64
# -Medical Fee Region: string
# -Carrier Type: string
# -Age at Injury: Int64
# -County of Injury: string
# Feature log_Average Weekly Wage is already in scaling list
# Feature Alternative Dispute Resolution is already in scaling list
# Feature COVID-19 Indicator is already in scaling list
# Column Carrier Type has too many unique values for oneHot encoding: 8
# ony 5 allowed, change the parameter if needed
# Feature fe_Carrier Type is already in scaling list
# Column Medical Fee Region has too many unique values for oneHot encoding: 5
# ony 5 allowed, change the parameter if needed
# Feature fe_Medical Fee Region is already in scaling list
# Column County of Injury has too many unique values for oneHot encoding: 63
# ony 5 allowed, change the parameter if needed
# Feature fe_County of Injury is already in scaling list
# Feature Attorney/Representative is already in scaling list
# Feature Age is already in scaling list
# Feature First Hearing Month is already in scaling list
# Feature First Hearing Year is already in scaling list
# Feature Accident Month is already in scaling list
# Feature Accident Year is already in scaling list
# Feature C-2 Month is already in scaling list
# Feature C-2 Year is already in scaling list
# Feature C-3 Month is already in scaling list
# Feature C-3 Year is already in scaling list
# Feature Assembly Month is already in scaling list
# Feature Assembly Year is already in scaling list
# Feature fe_WCIO Cause of Injury Code is already in scaling list
# Feature fe_Zip Code is already in scaling list
# Feature fe_WCIO Part Of Body Code is already in scaling list
# Feature fe_WCIO Nature of Injury Code is already in scaling list
# Feature fe_Industry Code is already in scaling list
# df after transformation_pipeline: (459220, 45)
# scaling_cols: ['Age at Injury', 'Average Weekly Wage', 'Birth Year', 'IME-4 Count', 'Industry Code', 'WCIO Cause of Injury Code', 'WCIO Nature of Injury Code', 'WCIO Part Of Body Code', 'Number of Dependents', 'log_Average Weekly Wage', 'fe_Carrier Type', 'fe_Medical Fee Region', 'fe_County of Injury', 'Age', 'Accident Month', 'Accident Year', 'C-2 Month', 'C-2 Year', 'C-3 Month', 'C-3 Year', 'Assembly Month', 'Assembly Year', 'fe_WCIO Cause of Injury Code', 'fe_Zip Code', 'fe_WCIO Part Of Body Code', 'fe_WCIO Nature of Injury Code', 'fe_Industry Code']
# <class 'pandas.core.frame.DataFrame'>
# Index: 459220 entries, 5877274 to 5803696
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Age at Injury                  459220 non-null  Int64
#  1   Average Weekly Wage            459220 non-null  float64
#  2   Birth Year                     459220 non-null  Int64
#  3   IME-4 Count                    459220 non-null  Int64
#  4   Industry Code                  459220 non-null  Int64
#  5   WCIO Cause of Injury Code      459220 non-null  Int64
#  6   WCIO Nature of Injury Code     459220 non-null  Int64
#  7   WCIO Part Of Body Code         459220 non-null  Int64
#  8   Number of Dependents           459220 non-null  Int64
#  9   log_Average Weekly Wage        459220 non-null  float64
#  10  fe_Carrier Type                459220 non-null  float64
#  11  fe_Medical Fee Region          459220 non-null  float64
#  12  fe_County of Injury            459220 non-null  float64
#  13  Age                            459220 non-null  Int64
#  14  Accident Month                 459220 non-null  Int64
#  15  Accident Year                  459220 non-null  Int64
#  16  C-2 Month                      459220 non-null  Int64
#  17  C-2 Year                       459220 non-null  Int64
#  18  C-3 Month                      459220 non-null  Int64
#  19  C-3 Year                       459220 non-null  Int64
#  20  Assembly Month                 459220 non-null  Int64
#  21  Assembly Year                  459220 non-null  Int64
#  22  fe_WCIO Cause of Injury Code   459220 non-null  float64
#  23  fe_Zip Code                    459220 non-null  float64
#  24  fe_WCIO Part Of Body Code      459220 non-null  float64
#  25  fe_WCIO Nature of Injury Code  459220 non-null  float64
#  26  fe_Industry Code               459220 non-null  float64
# dtypes: Int64(17), float64(10)
# memory usage: 105.5 MB
# info: None
# <class 'pandas.core.frame.DataFrame'>
# Index: 459220 entries, 5877274 to 5803696
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Alternative Dispute Resolution  459220 non-null  int64
#  1   Attorney/Representative         459220 non-null  int64
#  2   Carrier Name                    459220 non-null  string
#  3   Carrier Type                    459220 non-null  string
#  4   County of Injury                459220 non-null  string
#  5   COVID-19 Indicator              459220 non-null  int64
#  6   District Name                   459220 non-null  object
#  7   Gender                          459220 non-null  string
#  8   Medical Fee Region              459220 non-null  string
#  9   Zip Code                        459220 non-null  Int64
#  10  First Hearing Month             459220 non-null  Int64
#  11  First Hearing Year              459220 non-null  Int64
#  12  Gender_F                        459220 non-null  float64
#  13  Gender_M                        459220 non-null  float64
#  14  Gender_U                        459220 non-null  float64
#  15  Gender_X                        459220 non-null  float64
#  16  Age at Injury                   459220 non-null  float64
#  17  Average Weekly Wage             459220 non-null  float64
#  18  Birth Year                      459220 non-null  float64
#  19  IME-4 Count                     459220 non-null  float64
#  20  Industry Code                   459220 non-null  float64
#  21  WCIO Cause of Injury Code       459220 non-null  float64
#  22  WCIO Nature of Injury Code      459220 non-null  float64
#  23  WCIO Part Of Body Code          459220 non-null  float64
#  24  Number of Dependents            459220 non-null  float64
#  25  log_Average Weekly Wage         459220 non-null  float64
#  26  fe_Carrier Type                 459220 non-null  float64
#  27  fe_Medical Fee Region           459220 non-null  float64
#  28  fe_County of Injury             459220 non-null  float64
#  29  Age                             459220 non-null  float64
#  30  Accident Month                  459220 non-null  float64
#  31  Accident Year                   459220 non-null  float64
#  32  C-2 Month                       459220 non-null  float64
#  33  C-2 Year                        459220 non-null  float64
#  34  C-3 Month                       459220 non-null  float64
#  35  C-3 Year                        459220 non-null  float64
#  36  Assembly Month                  459220 non-null  float64
#  37  Assembly Year                   459220 non-null  float64
#  38  fe_WCIO Cause of Injury Code    459220 non-null  float64
#  39  fe_Zip Code                     459220 non-null  float64
#  40  fe_WCIO Part Of Body Code       459220 non-null  float64
#  41  fe_WCIO Nature of Injury Code   459220 non-null  float64
#  42  fe_Industry Code                459220 non-null  float64
# dtypes: Int64(3), float64(31), int64(3), object(1), string(5)
# memory usage: 155.5+ MB

# %%
pr.update_status('valid')
print("------------updates---------------------")
pr.update_casted_cols()
print("------------set_casting---------------------")
pr.set_castings(X_valid)
print("------------pipeline---------------------")
df_valid = pr.cast_pipeline(X_valid)
print("df after cast_pipeline:", df_valid.shape)
print("------------fillna---------------------")
pr.update_fillna_list(df_valid)   
df_valid = pr.fillna_pipeline(df_valid)
print("df after fillna_pipeline:", df_valid.shape)
print("------------transformation---------------------")
pr.set_transformations(df_valid)
df_valid = pr.transformation_pipeline(df_valid)
print("df after transformation_pipeline:", df_valid.shape)
df_valid = pr.scaling_pipeline(df_valid)
df_valid = df_valid.drop(columns=['Agreement Reached', 'WCB Decision'])

df_valid.info()
# Out:
# ------------updates---------------------
# ------------set_casting---------------------
# Columns that are not casted:
# -WCB Decision: object
# ------------pipeline---------------------
# Feature Carrier Type is already in scaling list
# Feature Zip Code is already in scaling list
# 'Industry Code Description'
# -Column Industry Code Description not found
# "['Industry Code Description'] not found in axis"
# -Column Industry Code Description not found
# "['OIICS Nature of Injury Description'] not found in axis"
# -Column OIICS Nature of Injury Description not found
# "['WCIO Cause of Injury Description'] not found in axis"
# -Column WCIO Cause of Injury Description not found
# "['WCIO Nature of Injury Description'] not found in axis"
# -Column WCIO Nature of Injury Description not found
# "['WCIO Part Of Body Description'] not found in axis"
# -Column WCIO Part Of Body Description not found
# 'Industry Code Description'
# -Column Industry Code Description not found
# df after cast_pipeline: (114806, 26)
# ------------fillna---------------------
# extended fillna_list: [('Age at Injury', 'median'), ('Average Weekly Wage', 'median'), ('Birth Year', 'median'), ('IME-4 Count', 'median'), ('Industry Code', 'median'), ('WCIO Cause of Injury Code', 'median'), ('WCIO Nature of Injury Code', 'median'), ('WCIO Part Of Body Code', 'median'), ('Zip Code', 'median'), ('Agreement Reached', 'median'), ('Number of Dependents', 'median'), ('Accident Date', 'mode'), ('Alternative Dispute Resolution', 'mode'), ('Assembly Date', 'mode'), ('Attorney/Representative', 'mode'), ('C-2 Date', 'mode'), ('C-3 Date', 'mode'), ('Carrier Name', 'mode'), ('Carrier Type', 'mode'), ('County of Injury', 'mode'), ('COVID-19 Indicator', 'mode'), ('District Name', 'mode'), ('First Hearing Date', 'mode'), ('Gender', 'mode'), ('Medical Fee Region', 'mode'), ('WCB Decision', 'mode')]
# nans in the beginning: 276995
# Column Age at Injury is filled with median ->num nan: 0
# Column Average Weekly Wage is filled with median ->num nan: 0
# Column Birth Year is filled with median ->num nan: 0
# Column IME-4 Count is filled with median ->num nan: 0
# Column Industry Code is filled with median ->num nan: 0
# Column WCIO Cause of Injury Code is filled with median ->num nan: 0
# Column WCIO Nature of Injury Code is filled with median ->num nan: 0
# Column WCIO Part Of Body Code is filled with median ->num nan: 0
# Column Zip Code is filled with median ->num nan: 0
# Column Agreement Reached is filled with median ->num nan: 0
# Column Number of Dependents is filled with median ->num nan: 0
# Column Accident Date is filled with mode ->num nan: 0
# Column Alternative Dispute Resolution is filled with mode ->num nan: 0
# Column Assembly Date is filled with mode ->num nan: 0
# Column Attorney/Representative is filled with mode ->num nan: 0
# Column C-2 Date is filled with mode ->num nan: 0
# Column C-3 Date is filled with mode ->num nan: 0
# Column Carrier Name is filled with mode ->num nan: 0
# Column Carrier Type is filled with mode ->num nan: 0
# Column County of Injury is filled with mode ->num nan: 0
# Column COVID-19 Indicator is filled with mode ->num nan: 0
# Column District Name is filled with mode ->num nan: 0
# Column First Hearing Date is filled with mode ->num nan: 0
# Column Gender is filled with mode ->num nan: 0
# Column Medical Fee Region is filled with mode ->num nan: 0
# Column WCB Decision is filled with mode ->num nan: 0
# nans in the end: 0
# df after fillna_pipeline: (114806, 26)
# ------------transformation---------------------
# Warning: there are duplicates in the transformation list
# Columns that are not transformed:
# -Average Weekly Wage: float64
# -District Name: object
# -Agreement Reached: Int64
# -Carrier Name: string
# -WCB Decision: object
# -Number of Dependents: Int64
# -IME-4 Count: Int64
# -Gender: string
# -Birth Year: Int64
# -Medical Fee Region: string
# -Carrier Type: string
# -Age at Injury: Int64
# -County of Injury: string
# Feature log_Average Weekly Wage is already in scaling list
# Feature Alternative Dispute Resolution is already in scaling list
# Feature COVID-19 Indicator is already in scaling list
# Column Carrier Type has too many unique values for oneHot encoding: 8
# ony 5 allowed, change the parameter if needed
# Feature fe_Carrier Type is already in scaling list
# Column Medical Fee Region has too many unique values for oneHot encoding: 5
# ony 5 allowed, change the parameter if needed
# Feature fe_Medical Fee Region is already in scaling list
# Column County of Injury has too many unique values for oneHot encoding: 63
# ony 5 allowed, change the parameter if needed
# Feature fe_County of Injury is already in scaling list
# Feature Attorney/Representative is already in scaling list
# Feature Age is already in scaling list
# Feature First Hearing Month is already in scaling list
# Feature First Hearing Year is already in scaling list
# Feature Accident Month is already in scaling list
# Feature Accident Year is already in scaling list
# Feature C-2 Month is already in scaling list
# Feature C-2 Year is already in scaling list
# Feature C-3 Month is already in scaling list
# Feature C-3 Year is already in scaling list
# Feature Assembly Month is already in scaling list
# Feature Assembly Year is already in scaling list
# Feature fe_WCIO Cause of Injury Code is already in scaling list
# Feature fe_Zip Code is already in scaling list
# Feature fe_WCIO Part Of Body Code is already in scaling list
# Feature fe_WCIO Nature of Injury Code is already in scaling list
# Feature fe_Industry Code is already in scaling list
# 'First Hearing Date'
# Column First Hearing Date not found
# 'First Hearing Date'
# Column First Hearing Date not found
# "['First Hearing Date'] not found in axis"
# Column First Hearing Date not found
# 'Accident Date'
# Column Accident Date not found
# 'Accident Date'
# Column Accident Date not found
# "['Accident Date'] not found in axis"
# Column Accident Date not found
# 'C-2 Date'
# Column C-2 Date not found
# 'C-2 Date'
# Column C-2 Date not found
# "['C-2 Date'] not found in axis"
# Column C-2 Date not found
# 'C-3 Date'
# Column C-3 Date not found
# 'C-3 Date'
# Column C-3 Date not found
# "['C-3 Date'] not found in axis"
# Column C-3 Date not found
# 'Assembly Date'
# Column Assembly Date not found
# 'Assembly Date'
# Column Assembly Date not found
# "['Assembly Date'] not found in axis"
# Column Assembly Date not found
# Feature fe_WCIO Cause of Injury Code is already in scaling list
# Feature fe_Zip Code is already in scaling list
# Feature fe_WCIO Part Of Body Code is already in scaling list
# Feature fe_WCIO Nature of Injury Code is already in scaling list
# Feature fe_Industry Code is already in scaling list
# df after transformation_pipeline: (114806, 45)
# <class 'pandas.core.frame.DataFrame'>
# Index: 114806 entries, 6143035 to 6081600
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Alternative Dispute Resolution  114806 non-null  int64
#  1   Attorney/Representative         114806 non-null  int64
#  2   Carrier Name                    114806 non-null  string
#  3   Carrier Type                    114806 non-null  string
#  4   County of Injury                114806 non-null  string
#  5   COVID-19 Indicator              114806 non-null  int64
#  6   District Name                   114806 non-null  object
#  7   Gender                          114806 non-null  string
#  8   Medical Fee Region              114806 non-null  string
#  9   Zip Code                        114806 non-null  Int64
#  10  First Hearing Month             114806 non-null  Int64
#  11  First Hearing Year              114806 non-null  Int64
#  12  Gender_F                        114806 non-null  float64
#  13  Gender_M                        114806 non-null  float64
#  14  Gender_U                        114806 non-null  float64
#  15  Gender_X                        114806 non-null  float64
#  16  Age at Injury                   114806 non-null  float64
#  17  Average Weekly Wage             114806 non-null  float64
#  18  Birth Year                      114806 non-null  float64
#  19  IME-4 Count                     114806 non-null  float64
#  20  Industry Code                   114806 non-null  float64
#  21  WCIO Cause of Injury Code       114806 non-null  float64
#  22  WCIO Nature of Injury Code      114806 non-null  float64
#  23  WCIO Part Of Body Code          114806 non-null  float64
#  24  Number of Dependents            114806 non-null  float64
#  25  log_Average Weekly Wage         114806 non-null  float64
#  26  fe_Carrier Type                 114806 non-null  float64
#  27  fe_Medical Fee Region           114806 non-null  float64
#  28  fe_County of Injury             114806 non-null  float64
#  29  Age                             114806 non-null  float64
#  30  Accident Month                  114806 non-null  float64
#  31  Accident Year                   114806 non-null  float64
#  32  C-2 Month                       114806 non-null  float64
#  33  C-2 Year                        114806 non-null  float64
#  34  C-3 Month                       114806 non-null  float64
#  35  C-3 Year                        114806 non-null  float64
#  36  Assembly Month                  114806 non-null  float64
#  37  Assembly Year                   114806 non-null  float64
#  38  fe_WCIO Cause of Injury Code    114806 non-null  float64
#  39  fe_Zip Code                     114806 non-null  float64
#  40  fe_WCIO Part Of Body Code       114806 non-null  float64
#  41  fe_WCIO Nature of Injury Code   114806 non-null  float64
#  42  fe_Industry Code                114806 non-null  float64
# dtypes: Int64(3), float64(31), int64(3), object(1), string(5)
# memory usage: 38.9+ MB

# %%
df_valid.columns
# Out:
# Index(['Alternative Dispute Resolution', 'Attorney/Representative',
#        'Carrier Name', 'Carrier Type', 'County of Injury',
#        'COVID-19 Indicator', 'District Name', 'Gender', 'Medical Fee Region',
#        'Zip Code', 'First Hearing Month', 'First Hearing Year', 'Gender_F',
#        'Gender_M', 'Gender_U', 'Gender_X', 'Age at Injury',
#        'Average Weekly Wage', 'Birth Year', 'IME-4 Count', 'Industry Code',
#        'WCIO Cause of Injury Code', 'WCIO Nature of Injury Code',
#        'WCIO Part Of Body Code', 'Number of Dependents',
#        'log_Average Weekly Wage', 'fe_Carrier Type', 'fe_Medical Fee Region',
#        'fe_County of Injury', 'Age', 'Accident Month', 'Accident Year',
#        'C-2 Month', 'C-2 Year', 'C-3 Month', 'C-3 Year', 'Assembly Month',
#        'Assembly Year', 'fe_WCIO Cause of Injury Code', 'fe_Zip Code',
#        'fe_WCIO Part Of Body Code', 'fe_WCIO Nature of Injury Code',
#        'fe_Industry Code'],
#       dtype='object')

# %%
X_valid
# Out:
#                   Age at Injury  Alternative Dispute Resolution  \
# Claim Identifier
# 6143035                      42                               0
# 5525593                      59                               0
# 5539202                      37                               0
# 5578055                      29                               0
# 5473728                      49                               0
# ...                         ...                             ...
# 5744019                      49                               0
# 5403940                      23                               0
# 6090655                      21                               0
# 5948282                      69                               0
# 6081600                      38                               0
#
#                   Attorney/Representative  Average Weekly Wage  Birth Year  \
# Claim Identifier
# 6143035                                 0                 0.00        1980
# 5525593                                 1               848.59        1961
# 5539202                                 1               720.88        1982
# 5578055                                 1              1150.00        1991
# 5473728                                 1              1612.57        1970
# ...                                   ...                  ...         ...
# 5744019                                 1               559.21        1971
# 5403940                                 1               603.89        1996
# 6090655                                 0                 0.00        2001
# 5948282                                 0              1393.61        1951
# 6081600                                 0                 0.00        1984
#
#                                    Carrier Name Carrier Type County of Injury  \
# Claim Identifier
# 6143035                        AIU INSURANCE CO           1A            KINGS
# 5525593                    STATE INSURANCE FUND           2A          GENESEE
# 5539202           HARTFORD ACCIDENT & INDEMNITY           1A           ORANGE
# 5578055                POLICE, FIRE, SANITATION           3A           QUEENS
# 5473728                    STATE INSURANCE FUND           2A           NASSAU
# ...                                         ...          ...              ...
# 5744019                STATE NATIONAL INSURANCE           1A            BRONX
# 5403940                STATE NATIONAL INSURANCE           1A            BRONX
# 6090655                        AIU INSURANCE CO           1A       RENSSELAER
# 5948282                 CHARTER OAK FIRE INS CO           1A           ORANGE
# 6081600           STARR SPECIALTY INSURANCE CO.           1A            BRONX
#
#                   COVID-19 Indicator District Name  ... C-2 Year  C-3 Month  \
# Claim Identifier                                    ...
# 6143035                            0           NYC  ...     2022          9
# 5525593                            0     ROCHESTER  ...     2020          9
# 5539202                            0        ALBANY  ...     2020          2
# 5578055                            0           NYC  ...     2021         10
# 5473728                            0           NYC  ...     2020          4
# ...                              ...           ...  ...      ...        ...
# 5744019                            0           NYC  ...     2021          6
# 5403940                            0           NYC  ...     2020          1
# 6090655                            1        ALBANY  ...     2022          9
# 5948282                            0        ALBANY  ...     2022          9
# 6081600                            0           NYC  ...     2022          9
#
#                   C-3 Year Assembly Month  Assembly Year  \
# Claim Identifier
# 6143035               2021             11           2022
# 5525593               2021              7           2020
# 5539202               2021              8           2020
# 5578055               2020             10           2020
# 5473728               2020              4           2020
# ...                    ...            ...            ...
# 5744019               2021              6           2021
# 5403940               2020              1           2020
# 6090655               2021              9           2022
# 5948282               2021              3           2022
# 6081600               2021              9           2022
#
#                   fe_WCIO Cause of Injury Code  fe_Zip Code  \
# Claim Identifier
# 6143035                               0.016003     0.016003
# 5525593                               0.036416     0.036416
# 5539202                               0.018773     0.018773
# 5578055                               0.160781     0.160781
# 5473728                               0.160781     0.160781
# ...                                        ...          ...
# 5744019                               0.036416     0.036416
# 5403940                               0.036416     0.036416
# 6090655                               0.076186     0.076186
# 5948282                               0.036416     0.036416
# 6081600                               0.064938     0.064938
#
#                   fe_WCIO Part Of Body Code  fe_WCIO Nature of Injury Code  \
# Claim Identifier
# 6143035                            0.016003                       0.016003
# 5525593                            0.036416                       0.036416
# 5539202                            0.018773                       0.018773
# 5578055                            0.160781                       0.160781
# 5473728                            0.160781                       0.160781
# ...                                     ...                            ...
# 5744019                            0.036416                       0.036416
# 5403940                            0.036416                       0.036416
# 6090655                            0.076186                       0.076186
# 5948282                            0.036416                       0.036416
# 6081600                            0.064938                       0.064938
#
#                  fe_Industry Code
# Claim Identifier
# 6143035                  0.016003
# 5525593                  0.036416
# 5539202                  0.018773
# 5578055                  0.160781
# 5473728                  0.160781
# ...                           ...
# 5744019                  0.036416
# 5403940                  0.036416
# 6090655                  0.076186
# 5948282                  0.036416
# 6081600                  0.064938
#
# [114806 rows x 41 columns]

# %%
df_valid
# Out:
#                   Alternative Dispute Resolution  Attorney/Representative  \
# Claim Identifier
# 6143035                                        0                        0
# 5525593                                        0                        1
# 5539202                                        0                        1
# 5578055                                        0                        1
# 5473728                                        0                        1
# ...                                          ...                      ...
# 5744019                                        0                        1
# 5403940                                        0                        1
# 6090655                                        0                        0
# 5948282                                        0                        0
# 6081600                                        0                        0
#
#                                    Carrier Name Carrier Type County of Injury  \
# Claim Identifier
# 6143035                        AIU INSURANCE CO           1A            KINGS
# 5525593                    STATE INSURANCE FUND           2A          GENESEE
# 5539202           HARTFORD ACCIDENT & INDEMNITY           1A           ORANGE
# 5578055                POLICE, FIRE, SANITATION           3A           QUEENS
# 5473728                    STATE INSURANCE FUND           2A           NASSAU
# ...                                         ...          ...              ...
# 5744019                STATE NATIONAL INSURANCE           1A            BRONX
# 5403940                STATE NATIONAL INSURANCE           1A            BRONX
# 6090655                        AIU INSURANCE CO           1A       RENSSELAER
# 5948282                 CHARTER OAK FIRE INS CO           1A           ORANGE
# 6081600           STARR SPECIALTY INSURANCE CO.           1A            BRONX
#
#                   COVID-19 Indicator District Name Gender Medical Fee Region  \
# Claim Identifier
# 6143035                            0           NYC      F                 IV
# 5525593                            0     ROCHESTER      M                  I
# 5539202                            0        ALBANY      M                III
# 5578055                            0           NYC      M                 IV
# 5473728                            0           NYC      M                 IV
# ...                              ...           ...    ...                ...
# 5744019                            0           NYC      M                 IV
# 5403940                            0           NYC      M                III
# 6090655                            1        ALBANY      M                  I
# 5948282                            0        ALBANY      M                 II
# 6081600                            0           NYC      M                 IV
#
#                   Zip Code  ...  C-2 Year  C-3 Month  C-3 Year  \
# Claim Identifier            ...
# 6143035              11232  ...       0.5        5.0       0.0
# 5525593              14525  ...      -0.5        5.0       0.0
# 5539202              10940  ...      -0.5       -2.0       0.0
# 5578055              11436  ...       0.0        6.0      -1.0
# 5473728              11758  ...      -0.5        0.0      -1.0
# ...                    ...  ...       ...        ...       ...
# 5744019              10455  ...       0.0        2.0       0.0
# 5403940              10950  ...      -0.5       -3.0      -1.0
# 6090655              12061  ...       0.5        5.0       0.0
# 5948282              12553  ...       0.5        5.0       0.0
# 6081600              10469  ...       0.5        5.0       0.0
#
#                   Assembly Month  Assembly Year  fe_WCIO Cause of Injury Code  \
# Claim Identifier
# 6143035                 0.666667            0.5                     -0.356335
# 5525593                 0.000000           -0.5                      0.184514
# 5539202                 0.166667           -0.5                     -0.282945
# 5578055                 0.500000           -0.5                      3.479633
# 5473728                -0.500000           -0.5                      3.479633
# ...                          ...            ...                           ...
# 5744019                -0.166667            0.0                      0.184514
# 5403940                -1.000000           -0.5                      0.184514
# 6090655                 0.333333            0.5                      1.238230
# 5948282                -0.666667            0.5                      0.184514
# 6081600                 0.333333            0.5                      0.940226
#
#                   fe_Zip Code  fe_WCIO Part Of Body Code  \
# Claim Identifier
# 6143035              7.269357                  -0.430052
# 5525593             17.491821                  -0.109496
# 5539202              8.656489                  -0.386554
# 5578055             79.772083                   1.843484
# 5473728             79.772083                   1.843484
# ...                       ...                        ...
# 5744019             17.491821                  -0.109496
# 5403940             17.491821                  -0.109496
# 6090655             37.407852                   0.515029
# 5948282             17.491821                  -0.109496
# 6081600             31.775354                   0.338406
#
#                   fe_WCIO Nature of Injury Code  fe_Industry Code
# Claim Identifier
# 6143035                               -0.487864         -0.464253
# 5525593                               -0.395895         -0.306786
# 5539202                               -0.475384         -0.442886
# 5578055                                0.164423          0.652579
# 5473728                                0.164423          0.652579
# ...                                         ...               ...
# 5744019                               -0.395895         -0.306786
# 5403940                               -0.395895         -0.306786
# 6090655                               -0.216716          0.000000
# 5948282                               -0.395895         -0.306786
# 6081600                               -0.267390         -0.086763
#
# [114806 rows x 43 columns]

# %%
X_valid.columns
# Out:
# Index(['Age at Injury', 'Alternative Dispute Resolution',
#        'Attorney/Representative', 'Average Weekly Wage', 'Birth Year',
#        'Carrier Name', 'Carrier Type', 'County of Injury',
#        'COVID-19 Indicator', 'District Name', 'Gender', 'IME-4 Count',
#        'Industry Code', 'Medical Fee Region', 'WCIO Cause of Injury Code',
#        'WCIO Nature of Injury Code', 'WCIO Part Of Body Code', 'Zip Code',
#        'Agreement Reached', 'WCB Decision', 'Number of Dependents',
#        'log_Average Weekly Wage', 'fe_Carrier Type', 'fe_Medical Fee Region',
#        'fe_County of Injury', 'Age', 'First Hearing Month',
#        'First Hearing Year', 'Accident Month', 'Accident Year', 'C-2 Month',
#        'C-2 Year', 'C-3 Month', 'C-3 Year', 'Assembly Month', 'Assembly Year',
#        'fe_WCIO Cause of Injury Code', 'fe_Zip Code',
#        'fe_WCIO Part Of Body Code', 'fe_WCIO Nature of Injury Code',
#        'fe_Industry Code'],
#       dtype='object')

# %%
"""pr.update_status('test')
print("------------updates---------------------")
pr.update_casted_cols()
print("------------set_casting---------------------")
pr.set_castings(test)
print("------------pipeline---------------------")
df_test = pr.cast_pipeline(test)
print("df after cast_pipeline:", df_test.shape)
print("------------fillna---------------------")
pr.update_fillna_list(df_test)   
df_test = pr.fillna_pipeline(df_test)
print("df after fillna_pipeline:", df_test.shape)
print("------------transformation---------------------")
pr.set_transformations(df_test)
df_test = pr.transformation_pipeline(df_test)
print("df after transformation_pipeline:", df_test.shape)
df_test = pr.scaling_pipeline(df_test)
#drop the columns 'Agreement Reached', 'WCB Decision'
df_valid = df_valid.drop(columns=['Agreement Reached', 'WCB Decision'])
df_test.info()"""
# Out:
# 'pr.update_status(\'test\')\nprint("------------updates---------------------")\npr.update_casted_cols()\nprint("------------set_casting---------------------")\npr.set_castings(test)\nprint("------------pipeline---------------------")\ndf_test = pr.cast_pipeline(test)\nprint("df after cast_pipeline:", df_test.shape)\nprint("------------fillna---------------------")\npr.update_fillna_list(df_test)   \ndf_test = pr.fillna_pipeline(df_test)\nprint("df after fillna_pipeline:", df_test.shape)\nprint("------------transformation---------------------")\npr.set_transformations(df_test)\ndf_test = pr.transformation_pipeline(df_test)\nprint("df after transformation_pipeline:", df_test.shape)\ndf_test = pr.scaling_pipeline(df_test)\n#drop the columns \'Agreement Reached\', \'WCB Decision\'\ndf_valid = df_valid.drop(columns=[\'Agreement Reached\', \'WCB Decision\'])\ndf_test.info()'

# %% [markdown]
# # Pre SMOTE

# %%
num_cols = df_train.select_dtypes(include=['float64']).columns

# %%
corr = []
for col in df_train[num_cols].columns:
    corr.append(df_train[col].corr(y_hot_train[f'Claim Injury Type_{FEATURENUMBER}']))
corr = pd.Series(corr, index=df_train[num_cols].columns)
corr = corr.sort_values(ascending=False)    

plt.figure(figsize=(10, 10))
sns.barplot(x=corr.values, y=corr.index)
plt.title('Correlation with target variable')
plt.show()

# %%
abcorr = np.abs(corr)
abcorr = abcorr.sort_values(ascending=False)

plt.figure(figsize=(10, 10))
sns.barplot(x=abcorr.values, y=corr.index)
plt.title('Correlation with target variable')
plt.show()

# %%
s_corr = []
for col in df_train[num_cols].columns:
    s_col = leo.two_col_entropy_corr(df_train[col], y_hot_train[f'Claim Injury Type_{FEATURENUMBER}'])
    s_col = log((s_col +1)/2)
    s_corr.append(s_col)
    
s_corr = pd.Series(s_corr, index=df_train[num_cols].columns).sort_values(ascending=False)

plt.figure(figsize=(10, 10))
sns.barplot(x=s_corr, y=df_train[num_cols].columns)
plt.title(f'Correlation with Claim Injury Type_{FEATURENUMBER}')
plt.show()

# %% [markdown]
# ## RFE

# %%
# rfe for feature selection
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=0)
rfe = RFE(rf, n_features_to_select=10)
rfe.fit(df_train[num_cols], y_hot_train[f'Claim Injury Type_{FEATURENUMBER}'])

selected_columns = df_train[num_cols].columns[rfe.support_]

# %%
selected_columns
# Out:
# Index(['Age at Injury', 'Average Weekly Wage', 'IME-4 Count',
#        'WCIO Cause of Injury Code', 'WCIO Part Of Body Code',
#        'log_Average Weekly Wage', 'fe_County of Injury', 'Age', 'fe_Zip Code',
#        'fe_WCIO Nature of Injury Code'],
#       dtype='object')

# %% [markdown]
# ## manual selection based on the results of RFE

# %%
columns_to_run = ['Age','IME-4 Count',
                        'Alternative Dispute Resolution',                          
                        'log_Average Weekly Wage',
                        'COVID-19 Indicator',
                        'C-3 Month',
                        'Gender_F',
                        'Gender_M']

# %% [markdown]
# # SMOTE

# %%
#! pip install imblearn

# %%
filtered_y_hot = y_hot.loc[df_train.index]
filtered_array = filtered_y_hot.to_numpy()

# %%
from imblearn.over_sampling import SMOTE


smote = SMOTE(sampling_strategy='minority', random_state=42)

X_train_resampled, y_train_resampled = smote.fit_resample(df_train[columns_to_run], filtered_array)

print("Resampling completed successfully!")
# Out:
# Resampling completed successfully!

# %%
y_train_resampled_df = pd.DataFrame(y_train_resampled, columns=y_hot.columns)
y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'].value_counts()
# Out:
# Claim Injury Type_7
# 0    459134
# 1    233101
# Name: count, dtype: int64

# %% [markdown]
# ## feature selection

# %%
# correlation with target
corr = X_train_resampled.corrwith(y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'])
corr = corr.sort_values(ascending=False)

plt.figure(figsize=(10, 10))
sns.barplot(x=corr, y=corr.index)
plt.title(f'Correlation with Claim Injury Type_{FEATURENUMBER}')
plt.show()

# %%
#correation between the selected columns
corr = X_train_resampled.corr()

plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=False, cmap='coolwarm')
plt.title('Correlation between selected columns')
plt.show()

# %%
# remove the columns with high correlation
corr_matrix = corr.abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.7)]

# %%
entropy_corr_matrix = leo.entropy_corr(X_train_resampled)
sns.heatmap(entropy_corr_matrix, annot=False, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## model selection

# %%
# evaluate the classifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
model_score = []

# %% [markdown]
# #### report_and_save()

# %% [markdown]
# ### decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
# create a decision tree classifier
DecisionTreeClassifier_1 = DecisionTreeClassifier(random_state=0)

# train the classifier
DecisionTreeClassifier_1.fit(X_train_resampled, y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'])

y_pred_full = DecisionTreeClassifier_1.predict(df_valid[columns_to_run])


accuracy_full  = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full)

f1_full = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, average='macro')

cm = confusion_matrix(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, normalize='true')

model_score.append(("DecisionTreeClassifier",accuracy_full, f1_full, cm[0][0], cm[0][1], cm[1][0], cm[1][1]))

leo.report_and_save(DecisionTreeClassifier_1,
                    f'{FEATURENUMBER}_DecisionTreeClassifier_1',
                    y_pred_full,
                    y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'],
                    columns_to_run)
# Out:
# Accuracy: 0.9993380136926642
# Precision: 0.9998184702756157
# Recall: 0.9993380136926642

# %%
# import logistic regression
from sklearn.linear_model import LogisticRegression

# create a logistic regression classifier
LogisticRegression_1 = LogisticRegression(random_state=0)

# train the classifier
LogisticRegression_1.fit(X_train_resampled,y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'])

y_pred_full = LogisticRegression_1.predict(df_valid[columns_to_run])

accuracy_full  = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full)

f1_full = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, average='macro')

cm = confusion_matrix(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, normalize='true')


model_score.append(("LogisticRegression",accuracy_full, f1_full, cm[0][0], cm[0][1], cm[1][0], cm[1][1]))

leo.report_and_save(LogisticRegression_1,
                    f'{FEATURENUMBER}LogisticRegression_1',
                    LogisticRegression_1.predict(df_valid[columns_to_run]),
                    y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'],
                    columns_to_run)
# Out:
# Accuracy: 0.8520983223873316
# Precision: 0.9998940203975949
# Recall: 0.8520983223873316

# %% [markdown]
# ### random forest

# %%
random_state = 42

# import random forest classifier
from sklearn.ensemble import RandomForestClassifier

# create a random forest classifier
RandomForestClassifier_1 = RandomForestClassifier(random_state=random_state)

# train the classifier
RandomForestClassifier_1.fit(X_train_resampled, y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'])

# evaluate the classifier
y_pred_full = RandomForestClassifier_1.predict(df_valid[columns_to_run])

accuracy_full  = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full)

f1_full = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, average='macro')

cm = confusion_matrix(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, normalize='true')

model_score.append(("RandomForestClassifier",accuracy_full, f1_full, cm[0][0], cm[0][1], cm[1][0], cm[1][1]))

leo.report_and_save(RandomForestClassifier_1,
                    f'{FEATURENUMBER}RandomForestClassifier_1',
                    y_pred_full,
                    y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'],
                    columns_to_run)
# Out:
# Accuracy: 0.9995122206156473
# Precision: 0.9998083439981633
# Recall: 0.9995122206156473

# %% [markdown]
# # XGBoost

# %%
import xgboost 
from xgboost import XGBClassifier

# create a xgboost classifier
XGBClassifier_1 = XGBClassifier(random_state=random_state)
XGBClassifier_selected = XGBClassifier(random_state=random_state)
XGBClassifier_selected_2 = XGBClassifier(random_state=random_state)

# train the classifier
XGBClassifier_1.fit(X_train_resampled, y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'])

# evaluate the classifier
y_pred_full = XGBClassifier_1.predict(df_valid[columns_to_run])

accuracy_full  = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full)

f1_full = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, average='macro')

cm = confusion_matrix(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, normalize='true')

model_score.append(("XGBClassifier",accuracy_full, f1_full, cm[0][0], cm[0][1], cm[1][0], cm[1][1]))

leo.report_and_save(XGBClassifier_1,
                    f'{FEATURENUMBER}XGBClassifier_1',
                    y_pred_full,
                    y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'],
                    columns_to_run)
# Out:
# Accuracy: 0.9964635994634427
# Precision: 0.999808050802859
# Recall: 0.9964635994634427

# %% [markdown]
# # LightGBM

# %%
# import lightgbm classifier
from lightgbm import LGBMClassifier

# create a lightgbm classifier
LGBMClassifier_1 = LGBMClassifier(random_state=random_state)

# train the classifier
LGBMClassifier_1.fit(X_train_resampled, y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'])

# evaluate the classifier
y_pred_full = LGBMClassifier_1.predict(df_valid[columns_to_run])

accuracy_full  = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full)

f1_full = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, average='macro')

cm = confusion_matrix(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, normalize='true')

model_score.append(("LGBMClassifier",accuracy_full, f1_full, cm[0][0], cm[0][1], cm[1][0], cm[1][1]))

leo.report_and_save(LGBMClassifier_1, f'{FEATURENUMBER}LGBMClassifier_1', y_pred_full, y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], columns_to_run)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 233101, number of negative: 459134
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005277 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1534
# [LightGBM] [Info] Number of data points in the train set: 692235, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.336737 -> initscore=-0.677870
# [LightGBM] [Info] Start training from score -0.677870
# Accuracy: 0.9976307858474296
# Precision: 0.9998081632664515
# Recall: 0.9976307858474296

# %%
# multillayer perceptron
from sklearn.neural_network import MLPClassifier

# create a multilayer perceptron classifier
MLPClassifier_1 = MLPClassifier(random_state=random_state)

# train the classifier
MLPClassifier_1.fit(X_train_resampled, y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'])

# evaluate the classifier
y_pred_full = MLPClassifier_1.predict(df_valid[columns_to_run])

accuracy_full  = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full)

f1_full = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, average='macro')

cm = confusion_matrix(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, normalize='true')

model_score.append(("MLPClassifier",accuracy_full, f1_full, cm[0][0], cm[0][1], cm[1][0], cm[1][1]))

leo.report_and_save(MLPClassifier_1, f'{FEATURENUMBER}MLPClassifier_1', y_pred_full, y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], columns_to_run)
# Out:
# Accuracy: 0.9848352873543195
# Precision: 0.9998158123253654
# Recall: 0.9848352873543195

# %%
for x in model_score:
    print(x)
# Out:
# ('DecisionTreeClassifier', 0.9993380136926642, np.float64(0.5126549600048079), np.int64(114729), np.int64(66), np.int64(10), np.int64(1))
# ('LogisticRegression', 0.8520983223873316, np.float64(0.46065634057509897), np.int64(97816), np.int64(16979), np.int64(1), np.int64(10))
# ('RandomForestClassifier', 0.9995122206156473, np.float64(0.49987802540556553), np.int64(114750), np.int64(45), np.int64(11), np.int64(0))
# ('XGBClassifier', 0.9964635994634427, np.float64(0.49911433383070253), np.int64(114400), np.int64(395), np.int64(11), np.int64(0))
# ('LGBMClassifier', 0.9976307858474296, np.float64(0.4994069939827331), np.int64(114534), np.int64(261), np.int64(11), np.int64(0))
# ('MLPClassifier', 0.9848352873543195, np.float64(0.49675354608267075), np.int64(113064), np.int64(1731), np.int64(10), np.int64(1))
# ('LogisticRegression', 0.8520983223873316, np.float64(0.46065634057509897), np.float64(0.852092861187334), np.float64(0.14790713881266607), np.float64(0.09090909090909091), np.float64(0.9090909090909091))
# ('RandomForestClassifier', 0.9995122206156473, np.float64(0.49987802540556553), np.float64(0.999607996863975), np.float64(0.0003920031360250882), np.float64(1.0), np.float64(0.0))
# ('DecisionTreeClassifier', 0.9993380136926642, np.float64(0.5126549600048079), np.float64(0.9994250620671632), np.float64(0.0005749379328367961), np.float64(0.9090909090909091), np.float64(0.09090909090909091))
# ('XGBClassifier', 0.9964635994634427, np.float64(0.49911433383070253), np.float64(0.9965590835837798), np.float64(0.0034409164162202185), np.float64(1.0), np.float64(0.0))
# ('LGBMClassifier', 0.9976307858474296, np.float64(0.4994069939827331), np.float64(0.9977263818110544), np.float64(0.0022736181889455114), np.float64(1.0), np.float64(0.0))

# %%
"""# svm classifier
from sklearn.svm import SVC

# create a svm classifier
SVC_1 = SVC(random_state=random_state)
SVC_selected = SVC(random_state=random_state)
SVC_selected_2 = SVC(random_state=random_state)

# train the classifier
SVC_1.fit(df_train[num_cols], y_hot_train[f'Claim Injury Type_{FEATURENUMBER}'])
SVC_selected.fit(df_train[selected_cols], y_hot_train[f'Claim Injury Type_{FEATURENUMBER}'])
SVC_selected_2.fit(df_train[selected_cols_2], y_hot_train[f'Claim Injury Type_{FEATURENUMBER}'])

# evaluate the classifier
y_pred_full = SVC_1.predict(df_valid[num_cols])
y_pred_selected = SVC_selected.predict(df_valid[selected_cols])
y_pred_selected_2 = SVC_selected_2.predict(df_valid[selected_cols_2])

accuracy_full  = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full)
accuracy_selected = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_selected)
accuracy_selected_2 = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_selected_2)

f1_full = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, average='macro')
f1_selected = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_selected, average='macro')
f1_selected_2 = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_selected_2, average='macro')

model_full.append(("SVC",accuracy_full, f1_full))
model_selected.append(("SVC",accuracy_selected, f1_selected))
model_selected_2.append(("SVC",accuracy_selected_2, f1_selected_2))

"""

# %%
# plotting the results
model_full = pd.DataFrame(model_score, columns=['Model', 'Accuracy', 'F1','TN','FP','FN','TP'])

plt.figure(figsize=(10, 10))
sns.barplot(x='Model', y='Accuracy', data=model_full)
plt.title('Accuracy of the models')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.barplot(x='Model', y='F1', data=model_full)
plt.title('F1 of the models')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # plot th true negative

# %%
df_model_score = pd.DataFrame(model_score, columns=['Model', 'Accuracy', 'F1','TN','FP','FN','TP'], index = [x[0] for x in model_score])

# %%
df_model_score[['TN','FN']]
# Out:
#                                    TN         FN
# DecisionTreeClassifier  114729.000000  10.000000
# LogisticRegression       97816.000000   1.000000
# RandomForestClassifier  114750.000000  11.000000
# XGBClassifier           114400.000000  11.000000
# LGBMClassifier          114534.000000  11.000000
# MLPClassifier           113064.000000  10.000000
# LogisticRegression           0.852093   0.090909
# RandomForestClassifier       0.999608   1.000000
# DecisionTreeClassifier       0.999425   0.909091
# XGBClassifier                0.996559   1.000000
# LGBMClassifier               0.997726   1.000000
# MLPClassifier                0.984921   0.909091

# %%
# plot the tn and tp one next to the other for comparison

plt.figure(figsize=(10, 10))
df_model_score['TN'].plot(kind='bar')
plt.title('TN and FN of the models')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 10))
df_model_score['TP'].plot(kind='bar')
plt.title('TN and FN of the models')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import PredefinedSplit

# %%
# do grid search for the best parameters in logistic regression
from sklearn.model_selection import GridSearchCV

# create a logistic regression classifier
LogisticRegression_2 = LogisticRegression(random_state=0)

# define the grid
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
              'penalty': ['l1', 'l2'],
              'solver': ['liblinear']}

# create a grid search object
grid_search = GridSearchCV(LogisticRegression_2, param_grid, cv=5)

# train the classifier
grid_search.fit(X_train_resampled, y_train_resampled_df[f'Claim Injury Type_{FEATURENUMBER}'])

# evaluate the classifier
y_pred_full = grid_search.predict(df_valid[columns_to_run])

accuracy_full  = accuracy_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full)

f1_full = f1_score(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, average='macro')

cm = confusion_matrix(y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], y_pred_full, normalize='true')

model_score.append(("LogisticRegression_GridSearch",accuracy_full, f1_full, cm[0][0], cm[0][1], cm[1][0], cm[1][1]))

leo.report_and_save(grid_search, f'{FEATURENUMBER}LogisticRegression_GridSearch', y_pred_full, y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'], columns_to_run)
# Out:
# Accuracy: 0.8617668066128948
# Precision: 0.9998941390370235
# Recall: 0.8617668066128948

# %%
y_hot_valid[f'Claim Injury Type_{FEATURENUMBER}'].value_counts()
# Out:
# Claim Injury Type_7
# 0.0    114795
# 1.0        11
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# data partition
from sklearn.model_selection import train_test_split

#filter methods
# spearman 
# chi-square
import scipy.stats as stats
from scipy.stats import chi2_contingency

#wrapper methods
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.feature_selection import RFE


# embedded methods
from sklearn.linear_model import LassoCV

import warnings
warnings.filterwarnings('ignore')

# %%
selected_cols_2

# %%
df_valid[selected_cols_2]

# %%
filtered_y_val = y_hot_valid.loc[df_valid[selected_cols_2].index]

# %%
from sklearn.svm import SVC
from sklearn.feature_selection import RFE

# %%
filtered_y_val

# %%
y_train_resampled_df

# %%
type7 = y_train_resampled_df['Claim Injury Type_7']

# %%
type7_val = filtered_y_val['Claim Injury Type_7']

# %%
selected_cols_2

# %%
df_valid[selected_cols_2]

# %%
selected_cols_2_ordered = ['Age', 'Average Weekly Wage', 'COVID-19 Indicator',
       'fe_Medical Fee Region', 'Gender_X', 'Gender_U',
       'Alternative Dispute Resolution']

# %%
X_train_resampled

# %%
#no of features
nof_list=np.arange(1,8)            
high_score=0
#Variable to store the optimum features
nof=0           
train_score_list =[]
val_score_list = []

for n in range(len(nof_list)):
    model = LogisticRegression()   
    #create RFE instance
    rfe = RFE(estimator = model,n_features_to_select = nof_list[n])
    
    #fit and transform for training data, transform for val data
    X_train_rfe = rfe.fit_transform(X_train_resampled,type7)
    X_val_rfe = rfe.transform(df_valid[selected_cols_2_ordered])
    
    model.fit(X_train_rfe,type7)
    
    #storing results on training data
    train_score = model.score(X_train_rfe,type7)
    train_score_list.append(train_score)
    
    #storing results on training data
    val_score = model.score(X_val_rfe,type7_val)
    val_score_list.append(val_score)
    
    #check best score
    if(val_score > high_score):
        high_score = val_score
        nof = nof_list[n]
        
        #adding mention of variables to keep
        features_to_select = pd.Series(rfe.support_, index = X_train_resampled.columns)
        
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
print(f"Features to select: \n{features_to_select}")

# %%
#######################################
######## K-Nearest Neighbors
#######################################
modelxg = XGBClassifier()

params = {
        'max_depth': [3, 5, 7],
        'learning_rate': [0.1, 0.01, 0.001],
        'subsample': [0.5, 0.7, 1],
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

                   
# with GridSearch
grid_search_lxg = GridSearchCV(
    estimator=modelxg,
    param_grid=params,
    scoring = 'f1_macro',
    verbose=1)

# %%
grid_results = grid_search_lxg.fit(X = X_train_resampled, y = type7)

# %%
#Parameter setting that gave the best results on the hold out data.
print(grid_results.best_params_ )

# %%
#Mean cross-validated score of the best_estimator
print('Best Score - KNN:', grid_results.best_score_ )

# %% [markdown]
# Best Model

# %%
final_model = modelxg.set_params(**grid_results.best_params_)

# %%
final_model.fit(X_train_resampled, type7)

# %%
labels_val = final_model.predict(df_valid[selected_cols_2_ordered])

# %%
print(classification_report(type7_val, labels_val))

# %%
print(confusion_matrix(type7_val, labels_val))

# %%
report_and_save(final_model, f'{FEATURENUMBER}final_model', labels_val, type7_val)

# %%
best_parameters = {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6}
