# %% [markdown]
# # tutorial on how to use  preProceser.py

# %%
# install libraries
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# %%
#get the data
train_path = "../Data/train_data.csv"
test_path = "../Data/test_data.csv"
dtype = {'Column29': 'str'}  # Replace 'Column29' with the actual column name that has mixed types

train = pd.read_csv(train_path, index_col='Claim Identifier', dtype=dtype, low_memory=False)
test = pd.read_csv(test_path, index_col='Claim Identifier', dtype=dtype, low_memory=False)

# %%
# drop all the rows that have missing values in Claim Injury Type
train = train.dropna(subset=['Claim Injury Type'])
y = train['Claim Injury Type']
X = train.drop(columns=['Claim Injury Type'])
# partition the data X, y and y_2bin
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
sys.path.append('../Library')
from preProcesser import PreProcessor

# %%
prep1 = PreProcessor()

# %%
prep1.set_start_features(test)
# Out:
# start features: Index(['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution',
#        'Assembly Date', 'Attorney/Representative', 'Average Weekly Wage',
#        'Birth Year', 'C-2 Date', 'C-3 Date', 'Carrier Name', 'Carrier Type',
#        'County of Injury', 'COVID-19 Indicator', 'District Name',
#        'First Hearing Date', 'Gender', 'IME-4 Count', 'Industry Code',
#        'Industry Code Description', 'Medical Fee Region',
#        'OIICS Nature of Injury Description', 'WCIO Cause of Injury Code',
#        'WCIO Cause of Injury Description', 'WCIO Nature of Injury Code',
#        'WCIO Nature of Injury Description', 'WCIO Part Of Body Code',
#        'WCIO Part Of Body Description', 'Zip Code', 'Number of Dependents'],
#       dtype='object')

# %%
prep1.append_columns_to_scale(['County of Injury'])

# %%
df_train = prep1.pipeline(X_train.copy(), fit_scaler=True, set_end_features=True)
# Out:
# features are not the same
# the features that have been discarded are {'Agreement Reached', 'WCB Decision'}
# 1)-------Numerical Features---------
# A) ---> dealing with the Average Weekly Wage
# B) ---> dealing with the Birth Year
# created ---> Age_
# IME-4 Count already in columns not to scale
# 2)-------Categorical Features---------
# A) ---> dealing with the zip code
# --- now zip code is numeric
# B) ---> dealing with Alternative Dispute Resolution
# Alternative Dispute Resolution already in columns not to scale
# C) ---> encoding the categorical features
# D) --->importing the lookup tables:
# 1. ---> lookup_carrier
# 2. ---> lookup_carrier_type
# 3. ---> lookup_cause_of_injury
# 4. ---> lookup_country
# 5. ---> lookup_district
# 6. ---> lookup_industry_code
# 7. ---> lookup_medical_fee
# 8. ---> lookup_nature_of_injury
# 9. ---> lookup_part_of_body
# 4)-------encoding the categorical features: ---------
# 1. ---> Carrier Name encoded in Carrier Code_
# Carrier Code_ already in columns not to scale
# 2. ---> Carrier Type encoded in Carrier Type Code
# 'Country of Injury'
# 4. ---> COVID-19 Indicator encoded
# COVID-19 Indicator already in columns not to scale
# 5. ---> District Name encoded in District Code_
# District Code already in columns not to scale
# 6. ---> Medical Fee Region encoded in Medical Fee Code_
# Medical Fee Code_ already in columns not to scale
# 7. ---> Carrier Type encoded in Carrier Type Code_
# Carrier Type Code already in columns not to scale
# appending the code columns to NOT scale
# appending Industry Code type: float64
# Industry Code already in columns not to scale
# appending Industry Code Description type: object
# Industry Code Description already in columns not to scale
# appending WCIO Cause of Injury Code type: float64
# WCIO Cause of Injury Code already in columns not to scale
# appending WCIO Nature of Injury Code type: float64
# WCIO Nature of Injury Code already in columns not to scale
# appending WCIO Part Of Body Code type: float64
# WCIO Part Of Body Code already in columns not to scale
# appending Zip Code type: int64
# Zip Code already in columns not to scale
# appending Carrier Code_ type: float64
# Carrier Code_ already in columns not to scale
# appending District Code type: int64
# District Code already in columns not to scale
# appending Medical Fee Code_ type: int64
# Medical Fee Code_ already in columns not to scale
# appending Carrier Type Code type: object
# Carrier Type Code already in columns not to scale
# 5) -------Date Features---------
# setin every date to date time
# 6) -------New Date Features---------
# A) ---> Accident Date year and month
# B) ---> Assembly Date year and month
# C) ---> C-2 year and month
# D) ---> C-3 year and month
# E) --->First Hearing year and month
# 7) -------appending Description columns to col_to_drop---------
# appending Industry Code Description type: object
# appending OIICS Nature of Injury Description type: float64
# appending WCIO Cause of Injury Description type: object
# appending WCIO Nature of Injury Description type: object
# appending WCIO Part Of Body Description type: object
# ->['WCB Decision', 'Average Weekly Wage', 'Carrier Name', 'District Name', 'Medical Fee Region', 'Carrier Type', 'Accident Date', 'Assembly Date', 'C-2 Date', 'C-3 Date', 'First Hearing Date', 'Industry Code Description', 'OIICS Nature of Injury Description', 'WCIO Cause of Injury Description', 'WCIO Nature of Injury Description', 'WCIO Part Of Body Description']
# 8)-------Encoding the categorical features---------
# A) ---> encoding Attorney/Representative
# B) ---> encoding Gender
# -------Frequency Encoding---------
# A) ---> County of Injury
# County of Injury already in columns not to scale
# -------------cleanUp-------------------
# --------------459220----------------
# --------------------------------
# ----> encoding done! created: Index(['Gender_F', 'Gender_M', 'Gender_U', 'Gender_X',
#        'Attorney/Representative_N', 'Attorney/Representative_Y',
#        'Carrier Type Code_1A', 'Carrier Type Code_2A', 'Carrier Type Code_3A',
#        'Carrier Type Code_4A', 'Carrier Type Code_5A', 'Carrier Type Code_5C',
#        'Carrier Type Code_5D', 'Carrier Type Code_UN',
#        'First Hearing held_False', 'First Hearing held_True'],
#       dtype='object')
# appending Gender unique values: ['F' 'M' 'U' 'X']
# appending Attorney/Representative unique values: ['N' 'Y']
# appending Carrier Type Code unique values: ['1A' '3A' 'UN' '2A' '4A' '5D' '5C' '5A']
# appending First Hearing held unique values: [False  True]
# Gender_F already in columns not to scale
# Gender_M already in columns not to scale
# Gender_U already in columns not to scale
# Gender_X already in columns not to scale
# Attorney/Representative_N already in columns not to scale
# Attorney/Representative_Y already in columns not to scale
# Carrier Type Code_1A already in columns not to scale
# Carrier Type Code_2A already in columns not to scale
# Carrier Type Code_3A already in columns not to scale
# Carrier Type Code_4A already in columns not to scale
# Carrier Type Code_5A already in columns not to scale
# Carrier Type Code_5C already in columns not to scale
# Carrier Type Code_5D already in columns not to scale
# Carrier Type Code_UN already in columns not to scale
# First Hearing held_False already in columns not to scale
# First Hearing held_True already in columns not to scale
# ------------encode_df--------------------
# --------------459220----------------
# --------------------------------
# dropping WCB Decision : object
# ----> columns dropped
# dropping Average Weekly Wage : float64
# ----> columns dropped
# dropping Carrier Name : object
# ----> columns dropped
# dropping District Name : object
# ----> columns dropped
# dropping Medical Fee Region : object
# ----> columns dropped
# dropping Carrier Type : object
# ----> columns dropped
# dropping Accident Date : datetime64[ns]
# ----> columns dropped
# dropping Assembly Date : datetime64[ns]
# ----> columns dropped
# dropping C-2 Date : datetime64[ns]
# ----> columns dropped
# dropping C-3 Date : datetime64[ns]
# ----> columns dropped
# dropping First Hearing Date : datetime64[ns]
# ----> columns dropped
# dropping Industry Code Description : object
# ----> columns dropped
# dropping OIICS Nature of Injury Description : float64
# ----> columns dropped
# dropping WCIO Cause of Injury Description : object
# ----> columns dropped
# dropping WCIO Nature of Injury Description : object
# ----> columns dropped
# dropping WCIO Part Of Body Description : object
# ----> columns dropped
# dropping Gender : object
# ----> columns dropped
# dropping Attorney/Representative : object
# ----> columns dropped
# dropping Carrier Type Code : object
# ----> columns dropped
# dropping First Hearing held : bool
# ----> columns dropped
# columns not dropped: []
# ------------drop_columns--------------------
# --------------459220----------------
# --------------------------------
# columns to scale: ['C-2 Month_', 'Accident Month_', 'C-3 Year_', 'First Hearing Month_', 'Assembly Year_', 'Accident Year_', 'C-2 Year_', 'C-3 Month_', 'Assembly Month_', 'log_Average Weekly Wage', 'Number of Dependents', 'First Hearing Year_', 'Age at Injury', 'Agreement Reached', 'Age_', 'Birth Year']
# ['C-2 Month_', 'Accident Month_', 'C-3 Year_', 'First Hearing Month_', 'Assembly Year_', 'Accident Year_', 'C-2 Year_', 'C-3 Month_', 'Assembly Month_', 'log_Average Weekly Wage', 'Number of Dependents', 'First Hearing Year_', 'Age at Injury', 'Agreement Reached', 'Age_', 'Birth Year']
# ------------choose_columns_to_scale--------------------
# columns to scale: C-2 Month_ type: float64
# columns to scale: Accident Month_ type: float64
# columns to scale: C-3 Year_ type: float64
# columns to scale: First Hearing Month_ type: float64
# columns to scale: Assembly Year_ type: int32
# columns to scale: Accident Year_ type: float64
# columns to scale: C-2 Year_ type: float64
# columns to scale: C-3 Month_ type: float64
# columns to scale: Assembly Month_ type: int32
# columns to scale: log_Average Weekly Wage type: float64
# columns to scale: Number of Dependents type: float64
# columns to scale: First Hearing Year_ type: float64
# columns to scale: Age at Injury type: float64
# columns to scale: Agreement Reached type: float64
# columns to scale: Age_ type: float64
# columns to scale: Birth Year type: float64
# /Users/leonardodicaterina/Documents/GitHub/Machine_Learning_G19/Notebooks/../Library/preProcesser.py:470: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.  -0.5  0.  ... -0.5  0.5  0. ]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.loc[:, self.get_columns_to_scale()] = self.scaler.fit_transform(df[self.get_columns_to_scale()])
# /Users/leonardodicaterina/Documents/GitHub/Machine_Learning_G19/Notebooks/../Library/preProcesser.py:470: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.83333333 -0.33333333 -0.83333333 ...  0.33333333 -0.5
#   0.33333333]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   df.loc[:, self.get_columns_to_scale()] = self.scaler.fit_transform(df[self.get_columns_to_scale()])
# scaler_fit----> scaling done
# ------------scaler_fit--------------------
# --------------459220----------------
# --------------------------------
# ----> scaling done
# ------------use_scaler--------------------
# --------------459220----------------
# --------------------------------
# end features: Index(['Age at Injury', 'Alternative Dispute Resolution', 'Birth Year',
#        'County of Injury', 'COVID-19 Indicator', 'IME-4 Count',
#        'Industry Code', 'WCIO Cause of Injury Code',
#        'WCIO Nature of Injury Code', 'WCIO Part Of Body Code', 'Zip Code',
#        'Agreement Reached', 'Number of Dependents', 'log_Average Weekly Wage',
#        'Age_', 'Carrier Code_', 'District Code', 'Medical Fee Code_',
#        'Accident Year_', 'Accident Month_', 'Assembly Year_',
#        'Assembly Month_', 'C-2 Year_', 'C-2 Month_', 'C-3 Year_', 'C-3 Month_',
#        'First Hearing Year_', 'First Hearing Month_', 'Gender_F', 'Gender_M',
#        'Gender_U', 'Gender_X', 'Attorney/Representative_N',
#        'Attorney/Representative_Y', 'Carrier Type Code_1A',
#        'Carrier Type Code_2A', 'Carrier Type Code_3A', 'Carrier Type Code_4A',
#        'Carrier Type Code_5A', 'Carrier Type Code_5C', 'Carrier Type Code_5D',
#        'Carrier Type Code_UN', 'First Hearing held_False',
#        'First Hearing held_True'],
#       dtype='object')
# columns to fillna: ['Alternative Dispute Resolution', 'Birth Year', 'Industry Code', 'WCIO Cause of Injury Code', 'WCIO Nature of Injury Code', 'WCIO Part Of Body Code', 'log_Average Weekly Wage', 'Age_', 'Carrier Code_', 'Accident Year_', 'Accident Month_', 'C-2 Year_', 'C-2 Month_', 'C-3 Year_', 'C-3 Month_', 'First Hearing Year_', 'First Hearing Month_']

# %%
df_train.head()
# Out:
#                   Age at Injury  Alternative Dispute Resolution  Birth Year  \
# Claim Identifier
# 5877274               -1.865784                             0.0  -85.958412
# 5482355               -1.835539                             0.0  -85.992439
# 5654730               -1.848771                             0.0  -85.977316
# 6029178               -1.758034                             0.0  -86.066163
# 6108114               -1.822306                             0.0  -86.001890
#
#                   County of Injury  COVID-19 Indicator  IME-4 Count  \
# Claim Identifier
# 5877274                      31788                   0          0.0
# 5482355                      19150                   0          0.0
# 5654730                      31788                   0          0.0
# 6029178                      24724                   0          0.0
# 6108114                      20634                   0          1.0
#
#                   Industry Code  WCIO Cause of Injury Code  \
# Claim Identifier
# 5877274                    72.0                  16.000000
# 5482355                    92.0                  57.000000
# 5654730                    23.0                  54.387119
# 6029178                    92.0                  31.000000
# 6108114                    62.0                  74.000000
#
#                   WCIO Nature of Injury Code  WCIO Part Of Body Code  ...  \
# Claim Identifier                                                      ...
# 5877274                            40.000000               35.000000  ...
# 5482355                            52.000000               31.000000  ...
# 5654730                            41.008404               39.723871  ...
# 6029178                            37.000000               -9.000000  ...
# 6108114                            49.000000               42.000000  ...
#
#                   Carrier Type Code_1A  Carrier Type Code_2A  \
# Claim Identifier
# 5877274                            1.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   1.0
#
#                   Carrier Type Code_3A  Carrier Type Code_4A  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            1.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            1.0                   0.0
# 6108114                            0.0                   0.0
#
#                   Carrier Type Code_5A  Carrier Type Code_5C  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   0.0
#
#                   Carrier Type Code_5D  Carrier Type Code_UN  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   1.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   0.0
#
#                   First Hearing held_False  First Hearing held_True
# Claim Identifier
# 5877274                                1.0                      0.0
# 5482355                                1.0                      0.0
# 5654730                                1.0                      0.0
# 6029178                                0.0                      1.0
# 6108114                                0.0                      1.0
#
# [5 rows x 44 columns]

# %%
prep1.get_columns_to_scale()
prep1.append_columns_to_scale('County of Injury')

# %%
prep1.scaler_fit(df_train)
# Out:
# scaler_fit----> scaling done
# /Users/leonardodicaterina/Documents/GitHub/Machine_Learning_G19/Notebooks/../Library/preProcesser.py:470: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.23395445 -0.1452576   0.23395445 ...  0.73162901 -0.30038707
#  -0.10072914]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, self.get_columns_to_scale()] = self.scaler.fit_transform(df[self.get_columns_to_scale()])
#                   Age at Injury  Alternative Dispute Resolution  Birth Year  \
# Claim Identifier
# 5877274               -0.913043                             0.0    1.109585
# 5482355               -0.217391                             0.0    0.209585
# 5654730               -0.521739                             0.0    0.609585
# 6029178                1.565217                             0.0   -1.740415
# 6108114                0.086957                             0.0   -0.040415
# ...                         ...                             ...         ...
# 5875495                0.565217                             0.0   -0.590415
# 5598826               -0.739130                             0.0    0.859585
# 5550948               -0.652174                             0.0    0.709585
# 5979080                0.826087                             0.0   -0.890415
# 5803696                1.173913                             0.0   -1.290415
#
#                   County of Injury  COVID-19 Indicator  IME-4 Count  \
# Claim Identifier
# 5877274                   0.233954                   0          0.0
# 5482355                  -0.145258                   0          0.0
# 5654730                   0.233954                   0          0.0
# 6029178                   0.021994                   0          0.0
# 6108114                  -0.100729                   0          1.0
# ...                            ...                 ...          ...
# 5875495                  -0.558616                   0          0.0
# 5598826                   0.233954                   1          0.0
# 5550948                   0.731629                   0          0.0
# 5979080                  -0.300387                   0          0.0
# 5803696                  -0.100729                   0          0.0
#
#                   Industry Code  WCIO Cause of Injury Code  \
# Claim Identifier
# 5877274                    72.0                  16.000000
# 5482355                    92.0                  57.000000
# 5654730                    23.0                  54.387119
# 6029178                    92.0                  31.000000
# 6108114                    62.0                  74.000000
# ...                         ...                        ...
# 5875495                    44.0                  97.000000
# 5598826                    71.0                  83.000000
# 5550948                    62.0                  99.000000
# 5979080                    62.0                  29.000000
# 5803696                    44.0                  29.000000
#
#                   WCIO Nature of Injury Code  WCIO Part Of Body Code  ...  \
# Claim Identifier                                                      ...
# 5877274                            40.000000               35.000000  ...
# 5482355                            52.000000               31.000000  ...
# 5654730                            41.008404               39.723871  ...
# 6029178                            37.000000               -9.000000  ...
# 6108114                            49.000000               42.000000  ...
# ...                                      ...                     ...  ...
# 5875495                            37.000000               35.000000  ...
# 5598826                            83.000000               91.000000  ...
# 5550948                            52.000000               42.000000  ...
# 5979080                            49.000000               56.000000  ...
# 5803696                            40.000000               10.000000  ...
#
#                   Carrier Type Code_1A  Carrier Type Code_2A  \
# Claim Identifier
# 5877274                            1.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   1.0
# ...                                ...                   ...
# 5875495                            0.0                   0.0
# 5598826                            1.0                   0.0
# 5550948                            1.0                   0.0
# 5979080                            1.0                   0.0
# 5803696                            1.0                   0.0
#
#                   Carrier Type Code_3A  Carrier Type Code_4A  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            1.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            1.0                   0.0
# 6108114                            0.0                   0.0
# ...                                ...                   ...
# 5875495                            0.0                   1.0
# 5598826                            0.0                   0.0
# 5550948                            0.0                   0.0
# 5979080                            0.0                   0.0
# 5803696                            0.0                   0.0
#
#                   Carrier Type Code_5A  Carrier Type Code_5C  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   0.0
# ...                                ...                   ...
# 5875495                            0.0                   0.0
# 5598826                            0.0                   0.0
# 5550948                            0.0                   0.0
# 5979080                            0.0                   0.0
# 5803696                            0.0                   0.0
#
#                   Carrier Type Code_5D  Carrier Type Code_UN  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   1.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   0.0
# ...                                ...                   ...
# 5875495                            0.0                   0.0
# 5598826                            0.0                   0.0
# 5550948                            0.0                   0.0
# 5979080                            0.0                   0.0
# 5803696                            0.0                   0.0
#
#                   First Hearing held_False  First Hearing held_True
# Claim Identifier
# 5877274                                1.0                      0.0
# 5482355                                1.0                      0.0
# 5654730                                1.0                      0.0
# 6029178                                0.0                      1.0
# 6108114                                0.0                      1.0
# ...                                    ...                      ...
# 5875495                                0.0                      1.0
# 5598826                                1.0                      0.0
# 5550948                                1.0                      0.0
# 5979080                                1.0                      0.0
# 5803696                                1.0                      0.0
#
# [459220 rows x 44 columns]

# %%
prep1.use_scaler(df_train)
# Out:
# ----> scaling done
#                   Age at Injury  Alternative Dispute Resolution   Birth Year  \
# Claim Identifier
# 5877274                    21.0                             0.0  2304.058097
# 5482355                    37.0                             0.0  2280.253097
# 5654730                    30.0                             0.0  2290.833097
# 6029178                    78.0                             0.0  2228.675597
# 6108114                    44.0                             0.0  2273.640597
# ...                         ...                             ...          ...
# 5875495                    55.0                             0.0  2259.093097
# 5598826                    25.0                             0.0  2297.445597
# 5550948                    27.0                             0.0  2293.478097
# 5979080                    61.0                             0.0  2251.158097
# 5803696                    69.0                             0.0  2240.578097
#
#                   County of Injury  COVID-19 Indicator  IME-4 Count  \
# Claim Identifier
# 5877274                  -0.719860                   0          0.0
# 5482355                  -0.719871                   0          0.0
# 5654730                  -0.719860                   0          0.0
# 6029178                  -0.719866                   0          0.0
# 6108114                  -0.719870                   0          1.0
# ...                            ...                 ...          ...
# 5875495                  -0.719884                   0          0.0
# 5598826                  -0.719860                   1          0.0
# 5550948                  -0.719845                   0          0.0
# 5979080                  -0.719876                   0          0.0
# 5803696                  -0.719870                   0          0.0
#
#                   Industry Code  WCIO Cause of Injury Code  \
# Claim Identifier
# 5877274                    72.0                  16.000000
# 5482355                    92.0                  57.000000
# 5654730                    23.0                  54.387119
# 6029178                    92.0                  31.000000
# 6108114                    62.0                  74.000000
# ...                         ...                        ...
# 5875495                    44.0                  97.000000
# 5598826                    71.0                  83.000000
# 5550948                    62.0                  99.000000
# 5979080                    62.0                  29.000000
# 5803696                    44.0                  29.000000
#
#                   WCIO Nature of Injury Code  WCIO Part Of Body Code  ...  \
# Claim Identifier                                                      ...
# 5877274                            40.000000               35.000000  ...
# 5482355                            52.000000               31.000000  ...
# 5654730                            41.008404               39.723871  ...
# 6029178                            37.000000               -9.000000  ...
# 6108114                            49.000000               42.000000  ...
# ...                                      ...                     ...  ...
# 5875495                            37.000000               35.000000  ...
# 5598826                            83.000000               91.000000  ...
# 5550948                            52.000000               42.000000  ...
# 5979080                            49.000000               56.000000  ...
# 5803696                            40.000000               10.000000  ...
#
#                   Carrier Type Code_1A  Carrier Type Code_2A  \
# Claim Identifier
# 5877274                            1.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   1.0
# ...                                ...                   ...
# 5875495                            0.0                   0.0
# 5598826                            1.0                   0.0
# 5550948                            1.0                   0.0
# 5979080                            1.0                   0.0
# 5803696                            1.0                   0.0
#
#                   Carrier Type Code_3A  Carrier Type Code_4A  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            1.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            1.0                   0.0
# 6108114                            0.0                   0.0
# ...                                ...                   ...
# 5875495                            0.0                   1.0
# 5598826                            0.0                   0.0
# 5550948                            0.0                   0.0
# 5979080                            0.0                   0.0
# 5803696                            0.0                   0.0
#
#                   Carrier Type Code_5A  Carrier Type Code_5C  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   0.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   0.0
# ...                                ...                   ...
# 5875495                            0.0                   0.0
# 5598826                            0.0                   0.0
# 5550948                            0.0                   0.0
# 5979080                            0.0                   0.0
# 5803696                            0.0                   0.0
#
#                   Carrier Type Code_5D  Carrier Type Code_UN  \
# Claim Identifier
# 5877274                            0.0                   0.0
# 5482355                            0.0                   0.0
# 5654730                            0.0                   1.0
# 6029178                            0.0                   0.0
# 6108114                            0.0                   0.0
# ...                                ...                   ...
# 5875495                            0.0                   0.0
# 5598826                            0.0                   0.0
# 5550948                            0.0                   0.0
# 5979080                            0.0                   0.0
# 5803696                            0.0                   0.0
#
#                   First Hearing held_False  First Hearing held_True
# Claim Identifier
# 5877274                                1.0                      0.0
# 5482355                                1.0                      0.0
# 5654730                                1.0                      0.0
# 6029178                                0.0                      1.0
# 6108114                                0.0                      1.0
# ...                                    ...                      ...
# 5875495                                0.0                      1.0
# 5598826                                1.0                      0.0
# 5550948                                1.0                      0.0
# 5979080                                1.0                      0.0
# 5803696                                1.0                      0.0
#
# [459220 rows x 44 columns]

# %%
pd.concat([df_train, y_train], axis=1).to_csv('../Data/train_data_preprocessed_4mypookybear.csv')

# %%
df_valid = prep1.pipeline(X_valid.copy(), set_end_features=False, fit_scaler=False)

# %%
df_train_pca = prep1.pipeline(X_train.copy(), set_end_features=False, fit_scaler=False, pca=True, n_components=.95, pca_fit = True)

# %%
df_train

# %% [markdown]
# # try PCA

# %%
X.columns

# %%
# make a pca
from sklearn.decomposition import PCA
pca = PCA(n_components=4)
X_pca = pca.fit_transform(X)
X_pca_df = pd.DataFrame(X_pca)

X_pca_valid = pca.transform(X_valid)

# %%
cumsum = np.cumsum(pca.explained_variance_ratio_)
plt.plot(cumsum)

# %%
X_pca_df = pd.DataFrame(X_pca)
X_pca_df

# %%
X_pca_valid = pca.transform(X_valid)
X_pca_valid

# %%
def check_representation(prep, df, y_df):

# %%
x = y_train.value_counts(normalize=True)

# %%
x.index

# %%
x.values

# %%
def representation_treshold(len_y,unique_y):
    reurn (len_y/unique_y)-(m.sqrt(len_y/8 *100 )/100)

# %%
for _ in x:
    print(_)

# %%
10/8

# %%
from math as m

m.sqrt(10/8 *100 )/100
